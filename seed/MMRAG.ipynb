# %% [markdown]
# # Multimoda RAG workflow
#
# Source: https://www.analyticsvidhya.com/blog/2024/09/guide-to-building-multimodal-rag-systems/?hl=en-US

# %% [markdown]
# ## Extracting Document Elements with Unstructured

# %%
from langchain_community.document_loaders import UnstructuredPDFLoader

doc = "../raw_data/pdf/vi-vneid.pdf"
loader = UnstructuredPDFLoader(file_path=doc,
                            strategy='hi_res',
                            extract_images_in_pdf=True,
                            infer_table_structure=True,
                            # section-based chunking
                            chunking_strategy="by_title", 
                            max_characters=4000, # max size of chunks
                            new_after_n_chars=4000, # preferred size of chunks
                            combine_text_under_n_chars=2000, # smaller chunks < 2000 chars will be combined into a larger chunk
                            mode='elements',
                            image_output_dir_path='./figures')
data = loader.load()
len(data)
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# ...

# %%
# [doc.metadata['category'] for doc in data]

# %%
print(data[1])
# Out:
# page_content='2.9.7 Thẻ BHXH ..................................................................................................... 93 2.9.8 Thông tin thuế ................................................................................................ 94 2.9.9 Người phụ thuộc ............................................................................................ 95 2.11.1 Thêm mới thông báo lưu trú ..................................................................... 98 2.11.2 Xóa thông tin người lưu trú ..................................................................... 117 2.11.3 Xem lịch sử thông báo lưu trú ................................................................. 118 2.12.1 Truy cập chức năng ................................................................................. 123 2.12.2 Tạo mới yêu cầu ...................................................................................... 125
#
# ...

# %%
print(data[10].page_content)
# Out:
# Hình 2.3-2 Giao diện đăng ký trên app Giao diện trang chủ mức 0
#
# Trường hợp tài khoản mức 0 bị xóa
#
# - Đăng nhập với tài khoản mức 0 bi xóa do không thực hiện đăng ký tài khoản mức, hiển thị thông báo:
#
# Théng bao Tai khoan tng dung VNeID cua ban da bi ngung hoat déng do khéng dang ky tai khoan dinh danh dién tir trong thdi gian quy dinh. Vui long dang ky lai tai knoan tng dung VNeID Déng
#
# Hình 2.3-3 Thông báo khi đăng nhập tài khoản đã bị xóa
#
# 24
#
# - Ấn nút “Đăng ký” sẽ chuyển sang giao diện Đăng ký tài khoản
#
# Trường hợp Đăng nhập với tài khoản mức 1
#
# Các bước thực hiện:
#
# - Bước 1: Tại màn hình đăng nhập, NSD nhập mật khẩu.
#
# Vui long nhap théng tin dang nhap dé tiép tuc Tran Hoai Nam ONrrrrrere; 55 Bang nhap Quén mat khéu DSi tai khoan D ‘4 Ping nhép bing Face ID wo
#
# Hình 2.3-4 Đăng nhập tài khoản mức 1/2
#
# - Bước 2: Màn hình hiển thị giao diện trang chủ mức 1
#
# 25
#
# ...

# %%
data[1].metadata['text_as_html']
# Out:
# '<table><tbody><tr><td colspan="2">XH... 2.9.8 Thong tin thu6...cccccccccccccsssessssessssecsssecsssessssessssessssesssscsssecsssecssseesssecsseecsseeessess 94</td></tr><tr><td colspan="2">2.9.9 NguOi Phy thuGe wo. cece eesecsesesscscseseessesssesseseeessesseesseseesseseesseesee 95</td></tr><tr><td colspan="2">2.10 DOi tdi KHOAN LA eee eeeeceeseeeeeeeeeessesssneeeecessssnnneeeeeessssnnnteeeessssnineeeessssenneeeeee 96</td></tr><tr><td colspan="2">2.11) Thong ba0 1 trie. cece cseescseeeecseeesssesseessesessseesessesenesseseeeeaeea 98</td></tr><tr><td>2.11.1 Thém moi thong bao lu trtt cece</td><td>ceeeceeseeeteeseeeteeseneteeneee 98</td></tr><tr><td>2.11.2 Xa thong tin ngudi LU trie eee ee</td><td>cesececeeeteeseseteeseeeeeseee 117</td></tr><tr><td colspan="2">2.11.3 Xem lich str thong b40 lw tri... ee eeee eee eeeeecseseeseseseteeseee 118</td></tr><tr><td colspan="2">1.12 Té gidc, tin bdo toi pham</td></tr><tr><td colspan="2">2.12.1 Truy cap Chive nang occ ces eeecsceecsecsecscsecsess
# ...

# %%
from IPython.display import HTML, display, Markdown
display(Markdown(data[6].metadata['text_as_html']))
# Out:
# <table><thead><tr><th>STT</th><th>Thuat ngir</th><th>Y nghia</th></tr></thead><tbody><tr><td>1</td><td>CCCD</td><td>Can cudc cong dan</td></tr><tr><td>2</td><td>| SDT</td><td>S6 dién thoai</td></tr><tr><td>3</td><td>NSD</td><td>Nguoi str dung</td></tr></tbody></table>
